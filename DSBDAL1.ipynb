# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df = pd.read_csv('Academic_Performance - Academic_Performance.csv')

# %%
df
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# 12408  SB11201420578809      M       Yes                 No       ACADEMIC
# 12409  SB11201420578812      F       Yes                Yes       ACADEMIC
# 12410  SB11201420583232      M        No                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  \
# ...

# %%
df.head()
# Out:
#          STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0  SB11201210000129      F       Yes                Yes       ACADEMIC
# 1  SB11201210000137      F       Yes                Yes       ACADEMIC
# 2  SB11201210005154      M        No                Yes       ACADEMIC
# 3  SB11201210007504      F       Yes                Yes       ACADEMIC
# 4  SB11201210007548      M       Yes                Yes       ACADEMIC
#
#          ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  COURSE 3 MARKS  \
# 0  INDUSTRIAL ENGINEERING            71.0            93.0            71.0
# 1  INDUSTRIAL ENGINEERING            97.0            38.0            86.0
# 2  ELECTRONIC ENGINEERING            17.0             1.0            18.0
# 3  INDUSTRIAL ENGINEERING            65.0            35.0            76.0
# 4  INDUSTRIAL ENGINEERING            94.0            94.0            98.0
#
#    COURSE 4 MARKS  COURSE 5 MARKS  PERCENTILE OVEARLL_GRADE
# ...

# %%
df.isnull().sum()
# Out:
# STUDENT_ID             0
# GENDER                22
# PLACEMENT             15
# HONOR_OPTED_OR_NOT    14
# EDUCATION_TYPE        15
# ACADEMIC_PROGRAM      34
# COURSE 1 MARKS        11
# COURSE 2 MARKS         8
# COURSE 3 MARKS        14
# COURSE 4 MARKS        14
# COURSE 5 MARKS        22
# PERCENTILE             0
# OVEARLL_GRADE          0
# dtype: int64

# %%
x = df['COURSE 1 MARKS'].median()
df['COURSE 1 MARKS'] = df['COURSE 1 MARKS'].fillna(x)
print(df['COURSE 1 MARKS'].head())
# Out:
# 0    71.0
# 1    97.0
# 2    17.0
# 3    65.0
# 4    94.0
# Name: COURSE 1 MARKS, dtype: float64

# %%
x = df['COURSE 2 MARKS'].median()
df['COURSE 2 MARKS'] = df['COURSE 2 MARKS'].fillna(x)
print(df['COURSE 2 MARKS'].head())
# Out:
# 0    93.0
# 1    38.0
# 2     1.0
# 3    35.0
# 4    94.0
# Name: COURSE 2 MARKS, dtype: float64

# %%
x = df['COURSE 3 MARKS'].median()
df['COURSE 3 MARKS'] = df['COURSE 3 MARKS'].fillna(x)
print(df['COURSE 3 MARKS'].head())
# Out:
# 0    71.0
# 1    86.0
# 2    18.0
# 3    76.0
# 4    98.0
# Name: COURSE 3 MARKS, dtype: float64

# %%
x = df['COURSE 4 MARKS'].median()
df['COURSE 4 MARKS'] = df['COURSE 4 MARKS'].fillna(x)
print(df['COURSE 4 MARKS'].head())
# Out:
# 0     93.0
# 1     98.0
# 2     43.0
# 3     80.0
# 4    100.0
# Name: COURSE 4 MARKS, dtype: float64

# %%
x = df['COURSE 5 MARKS'].median()
df['COURSE 5 MARKS'] = df['COURSE 5 MARKS'].fillna(x)
print(df['COURSE 5 MARKS'].head())
# Out:
# 0    79.0
# 1    78.0
# 2    22.0
# 3    48.0
# 4    71.0
# Name: COURSE 5 MARKS, dtype: float64

# %%
df.isnull().sum()
# Out:
# STUDENT_ID             0
# GENDER                22
# PLACEMENT             15
# HONOR_OPTED_OR_NOT    14
# EDUCATION_TYPE        15
# ACADEMIC_PROGRAM      34
# COURSE 1 MARKS         0
# COURSE 2 MARKS         0
# COURSE 3 MARKS         0
# COURSE 4 MARKS         0
# COURSE 5 MARKS         0
# PERCENTILE             0
# OVEARLL_GRADE          0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# STUDENT_ID            0
# GENDER                0
# PLACEMENT             0
# HONOR_OPTED_OR_NOT    0
# EDUCATION_TYPE        0
# ACADEMIC_PROGRAM      0
# COURSE 1 MARKS        0
# COURSE 2 MARKS        0
# COURSE 3 MARKS        0
# COURSE 4 MARKS        0
# COURSE 5 MARKS        0
# PERCENTILE            0
# OVEARLL_GRADE         0
# dtype: int64

# %%
def detect_outliers(data):
    outliers = []
    data = sorted(data)
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    IQR = Q3 - Q1

    print("Q1:", Q1)
    print("Q3:", Q3)
    print("IQR:", IQR)

    lower_bnd = Q1 - 1.5 * IQR
    upper_bnd = Q3 + 1.5 * IQR

    for i in data:
        if i < lower_bnd or i > upper_bnd:
            outliers.append(i)

    return list(set(outliers)), lower_bnd, upper_bnd

# %%
outliers,lower_bnd,upper_bnd = detect_outliers(df['COURSE 1 MARKS'])
# Out:
# Q1: 65.0
# Q3: 96.0
# IQR: 31.0

# %%
df['cleaned_course_1_marks'] = df['COURSE 1 MARKS'].apply(lambda x : x if lower_bnd<=x <= upper_bnd else np.nan)
df.head()
# Out:
#          STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0  SB11201210000129      F       Yes                Yes       ACADEMIC
# 1  SB11201210000137      F       Yes                Yes       ACADEMIC
# 2  SB11201210005154      M        No                Yes       ACADEMIC
# 3  SB11201210007504      F       Yes                Yes       ACADEMIC
# 4  SB11201210007548      M       Yes                Yes       ACADEMIC
#
#          ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  COURSE 3 MARKS  \
# 0  INDUSTRIAL ENGINEERING            71.0            93.0            71.0
# 1  INDUSTRIAL ENGINEERING            97.0            38.0            86.0
# 2  ELECTRONIC ENGINEERING            17.0             1.0            18.0
# 3  INDUSTRIAL ENGINEERING            65.0            35.0            76.0
# 4  INDUSTRIAL ENGINEERING            94.0            94.0            98.0
#
#    COURSE 4 MARKS  COURSE 5 MARKS  PERCENTILE OVEARLL_GRADE  \
# ...

# %%
df.isnull().sum()
# Out:
# STUDENT_ID                  0
# GENDER                      0
# PLACEMENT                   0
# HONOR_OPTED_OR_NOT          0
# EDUCATION_TYPE              0
# ACADEMIC_PROGRAM            0
# COURSE 1 MARKS              0
# COURSE 2 MARKS              0
# COURSE 3 MARKS              0
# COURSE 4 MARKS              0
# COURSE 5 MARKS              0
# PERCENTILE                  0
# OVEARLL_GRADE               0
# cleaned_course_1_marks    292
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# STUDENT_ID                0
# GENDER                    0
# PLACEMENT                 0
# HONOR_OPTED_OR_NOT        0
# EDUCATION_TYPE            0
# ACADEMIC_PROGRAM          0
# COURSE 1 MARKS            0
# COURSE 2 MARKS            0
# COURSE 3 MARKS            0
# COURSE 4 MARKS            0
# COURSE 5 MARKS            0
# PERCENTILE                0
# OVEARLL_GRADE             0
# cleaned_course_1_marks    0
# dtype: int64

# %%
detect_outliers(df['COURSE 2 MARKS'])
# Out:
# Q1: 43.0
# Q3: 86.0
# IQR: 43.0
# ([], np.float64(-21.5), np.float64(150.5))

# %%
detect_outliers(df['COURSE 3 MARKS'])
# Out:
# Q1: 37.0
# Q3: 85.0
# IQR: 48.0
# ([], np.float64(-35.0), np.float64(157.0))

# %%
detect_outliers(df['COURSE 4 MARKS'])
# Out:
# Q1: 52.0
# Q3: 88.0
# IQR: 36.0
# ([], np.float64(-2.0), np.float64(142.0))

# %%
detect_outliers(df['COURSE 5 MARKS'])
# Out:
# Q1: 28.0
# Q3: 81.0
# IQR: 53.0
# ([], np.float64(-51.5), np.float64(160.5))

# %%
detect_outliers(df['PERCENTILE'])
# Out:
# Q1: 53.0
# Q3: 91.0
# IQR: 38.0
# ([], np.float64(-4.0), np.float64(148.0))

# %%
#from sklearn.preprocessing import LabelEncoder
#le = LabelEncoder()

# %%
df['GENDER'] = le.fit_transform(df['GENDER'])
df.head()
# Out:
#          STUDENT_ID  GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0  SB11201210000129       0       Yes                Yes       ACADEMIC
# 1  SB11201210000137       0       Yes                Yes       ACADEMIC
# 3  SB11201210007504       0       Yes                Yes       ACADEMIC
# 4  SB11201210007548       1       Yes                Yes       ACADEMIC
# 5  SB11201210007568       0       Yes                Yes       ACADEMIC
#
#          ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  COURSE 3 MARKS  \
# 0  INDUSTRIAL ENGINEERING            71.0            93.0            71.0
# 1  INDUSTRIAL ENGINEERING            97.0            38.0            86.0
# 3  INDUSTRIAL ENGINEERING            65.0            35.0            76.0
# 4  INDUSTRIAL ENGINEERING            94.0            94.0            98.0
# 5  INDUSTRIAL ENGINEERING            86.0            15.0            32.0
#
#    COURSE 4 MARKS  COURSE 5 MARKS  PERCENTILE OVEARLL_GRADE  \
# ...

# %%
df['PLACEMENT'] = le.fit_transform(df['PLACEMENT'])
df.head()
# Out:
#          STUDENT_ID  GENDER  PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0  SB11201210000129       0          1                Yes       ACADEMIC
# 1  SB11201210000137       0          1                Yes       ACADEMIC
# 3  SB11201210007504       0          1                Yes       ACADEMIC
# 4  SB11201210007548       1          1                Yes       ACADEMIC
# 5  SB11201210007568       0          1                Yes       ACADEMIC
#
#          ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  COURSE 3 MARKS  \
# 0  INDUSTRIAL ENGINEERING            71.0            93.0            71.0
# 1  INDUSTRIAL ENGINEERING            97.0            38.0            86.0
# 3  INDUSTRIAL ENGINEERING            65.0            35.0            76.0
# 4  INDUSTRIAL ENGINEERING            94.0            94.0            98.0
# 5  INDUSTRIAL ENGINEERING            86.0            15.0            32.0
#
#    COURSE 4 MARKS  COURSE 5 MARKS  PERCENTILE OVEARLL_GRADE  \
# ...

# %%
df['HONOR_OPTED_OR_NOT'] = le.fit_transform(df['HONOR_OPTED_OR_NOT'])
df.head()
# Out:
#          STUDENT_ID  GENDER  PLACEMENT  HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0  SB11201210000129       0          1                   1       ACADEMIC
# 1  SB11201210000137       0          1                   1       ACADEMIC
# 3  SB11201210007504       0          1                   1       ACADEMIC
# 4  SB11201210007548       1          1                   1       ACADEMIC
# 5  SB11201210007568       0          1                   1       ACADEMIC
#
#          ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  COURSE 3 MARKS  \
# 0  INDUSTRIAL ENGINEERING            71.0            93.0            71.0
# 1  INDUSTRIAL ENGINEERING            97.0            38.0            86.0
# 3  INDUSTRIAL ENGINEERING            65.0            35.0            76.0
# 4  INDUSTRIAL ENGINEERING            94.0            94.0            98.0
# 5  INDUSTRIAL ENGINEERING            86.0            15.0            32.0
#
#    COURSE 4 MARKS  COURSE 5 MARKS  PERCENTILE OVEARLL_GRADE  \
# ...

# %%
df['Education_TYPE'] = le.fit_transform(df['EDUCATION_TYPE'])
df.head()
# Out:
#          STUDENT_ID  GENDER  PLACEMENT  HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0  SB11201210000129       0          1                   1       ACADEMIC
# 1  SB11201210000137       0          1                   1       ACADEMIC
# 3  SB11201210007504       0          1                   1       ACADEMIC
# 4  SB11201210007548       1          1                   1       ACADEMIC
# 5  SB11201210007568       0          1                   1       ACADEMIC
#
#          ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  COURSE 3 MARKS  \
# 0  INDUSTRIAL ENGINEERING            71.0            93.0            71.0
# 1  INDUSTRIAL ENGINEERING            97.0            38.0            86.0
# 3  INDUSTRIAL ENGINEERING            65.0            35.0            76.0
# 4  INDUSTRIAL ENGINEERING            94.0            94.0            98.0
# 5  INDUSTRIAL ENGINEERING            86.0            15.0            32.0
#
#    COURSE 4 MARKS  COURSE 5 MARKS  PERCENTILE OVEARLL_GRADE  \
# ...
