# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df = pd.read_csv('nba - nba.csv')
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2     John Holland  Boston Celtics      30       SG   27    6-5     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3     203
# 454      Raul Neto       Utah Jazz      25       PG   24    6-1     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26    7-3     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df['Number'] = pd.to_numeric(df['Number'], errors='coerce')

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# %%
df['Weight'] = pd.to_numeric(df['Weight'], errors='coerce')

# %%
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')

# %%
df['Position'] = df['Position'].astype('category')

# %%
df['Team'] = df['Team'].astype('category')

# %%
df.dtypes
# Out:
# Name          object
# Team        category
# Number         int64
# Position    category
# Age            int64
# Height        object
# Weight         int64
# College       object
# Salary       float64
# dtype: object

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.shape
# Out:
# (457, 9)

# %%
df['Position'].unique()
# Out:
# ['PG', 'SF', 'SG', 'PF', 'C']
# Categories (5, object): ['C', 'PF', 'PG', 'SF', 'SG']

# %%
df['Position'].dtype
# Out:
# CategoricalDtype(categories=['C', 'PF', 'PG', 'SF', 'SG'], ordered=False, categories_dtype=object)

# %%
df['Position'] = df['Position'].cat.rename_categories({
    'PG': 0,
    'SF': 1,
    'SG': 2,
    'PF': 3,
    'C': 4
})

# %%
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0        0   25    6-2     180
# 1      Jae Crowder  Boston Celtics      99        1   25    6-6     235
# 2     John Holland  Boston Celtics      30        2   27    6-5     205
# 3      R.J. Hunter  Boston Celtics      28        2   22    6-5     185
# 4    Jonas Jerebko  Boston Celtics       8        3   29   6-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41        3   20   6-10     234
# 453   Shelvin Mack       Utah Jazz       8        0   26    6-3     203
# 454      Raul Neto       Utah Jazz      25        0   24    6-1     179
# 455   Tibor Pleiss       Utah Jazz      21        4   26    7-3     256
# 456    Jeff Withey       Utah Jazz      24        4   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df['Height'] = le.fit_transform(df['Height'])

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0        0   25       6     180
# 1      Jae Crowder  Boston Celtics      99        1   25      10     235
# 2     John Holland  Boston Celtics      30        2   27       9     205
# 3      R.J. Hunter  Boston Celtics      28        2   22       9     185
# 4    Jonas Jerebko  Boston Celtics       8        3   29       4     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41        3   20       4     234
# 453   Shelvin Mack       Utah Jazz       8        0   26       7     203
# 454      Raul Neto       Utah Jazz      25        0   24       3     179
# 455   Tibor Pleiss       Utah Jazz      21        4   26      17     256
# 456    Jeff Withey       Utah Jazz      24        4   26      14     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df = df.drop('College',axis=1)

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# Salary      11
# dtype: int64

# %%
df_pg = df[df['Position']==0]
print(df_pg)
# Out:
#               Name                    Team  Number Position  Age  Height  \
# 0    Avery Bradley          Boston Celtics       0        0   25       6
# 8     Terry Rozier          Boston Celtics      12        0   22       6
# 9     Marcus Smart          Boston Celtics      36        0   22       8
# 11   Isaiah Thomas          Boston Celtics       4        0   27       1
# 19    Jarrett Jack           Brooklyn Nets       2        0   32       7
# ..             ...                     ...     ...      ...  ...     ...
# 440  Brian Roberts  Portland Trail Blazers       2        0   30       3
# 443     Trey Burke               Utah Jazz       3        0   23       3
# 445     Dante Exum               Utah Jazz      11        0   20      10
# 453   Shelvin Mack               Utah Jazz       8        0   26       7
# 454      Raul Neto               Utah Jazz      25        0   24       3
#
#      Weight     Salary
# 0       180  7730337.0
# 8       190  1824360.0
# ...

# %%
pg_mean = df_pg['Salary'].mean()

# %%
print(pg_mean)
# Out:
# 5077829.215909091

# %%
df_pg = df[df['Position'] == 0].copy()

# %%
pg_mean = df_pg['Salary'].mean()
df_pg['Salary'] = df_pg['Salary'].fillna(pg_mean)

# %%
print(df_pg['Salary'])
# Out:
# 0      7730337.0
# 8      1824360.0
# 9      3431040.0
# 11     6912869.0
# 19     6300000.0
#          ...
# 440    2854940.0
# 443    2658240.0
# 445    3777720.0
# 453    2433333.0
# 454     900000.0
# Name: Salary, Length: 92, dtype: float64
